# %% [markdown]
# <a href="https://colab.research.google.com/github/harshit123-beep/AI-Powered-Health-Diagnosis-App/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Save this snippet as "emergency_numbers.json"
{
  "India": {"Police": "100", "Fire": "101", "Ambulance": "102", "All-in-One": "112"},
  "USA": {"All Services": "911"},
  "UK": {"All Services": "999"},
  "Canada": {"All Services": "911"},
  "Australia": {"All Services": "000"},
  "Germany": {"Police": "110", "Ambulance/Fire": "112"}
}
